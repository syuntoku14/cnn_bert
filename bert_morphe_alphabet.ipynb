# %%
import torch
import torch.nn as nn
from torch.nn.utils import clip_grad_norm_
from torch.utils.data import Dataset, DataLoader
import numpy as np
from pytorch_pretrained_bert import BertModel, BertTokenizer
from bert_cnn_alphabet import *
import string
import re
import sys
import argparse
import torch.nn.utils.rnn as rnn
import torch.nn.functional as F

# import utils
from Interpreter import calculate_regularization, Interpreter

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
dataset = BertDataset(device)
dataloader = DataLoader(dataset, batch_size=512, shuffle=True)
# Out:
# 30522 -> 20361
# Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (20361 > 512). Running this sequence through BERT will result in indexing errors

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--num_epochs', type=int, default=100)
parser.add_argument('--embed_size', type=int, default=16)
parser.add_argument('--hidden_size', type=int, default=256)
parser.add_argument('--channel_size', type=int, default=32)
parser.add_argument('--batch_size', type=int, default=256)
parser.add_argument('--learning_rate', type=float, default=0.001)
parser.add_argument('--skip_train', type=bool, default=False)
args = parser.parse_args(["--num_epochs", "10",
                          "--embed_size", "8", "--hidden_size", "256",
                          "--batch_size", "256", 
                          "--learning_rate", "0.001",
                          "--channel_size", "32"])

CHAR_VOCAB_SIZE = 52
BERT_EMBED_DIM = 768
model = CNN_LM(char_vocab_size=CHAR_VOCAB_SIZE, 
        char_len=dataset.chars.shape[1], embed_dim=args.embed_size,
        chan_size=args.channel_size, hid_size=args.hidden_size,
        bert_hid_size=BERT_EMBED_DIM)
model.to(device)
model.load_state_dict(torch.load("data/bert_cnn.ckpt", map_location=torch.device('cpu')))
model.eval()
# Out:
# CNN_LM(
#   (embedding): Embedding(52, 8)
#   (convs): Sequential(
#     (0): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(8, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): Conv1dBlockBN(
#       (conv): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(2,), stride=(1,))
#         (1): Dropout(p=0.0, inplace=False)
#         (2): PReLU(num_parameters=1)
#         (3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (fc1): Linear(in_features=32, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=768, bias=True)
# )

# %% [markdown]
# # Test

# %%
dataset = BertDataset(device)
dataloader = DataLoader(dataset, batch_size=512, shuffle=True)
# Out:
# 30522 -> 20361
# Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (20361 > 512). Running this sequence through BERT will result in indexing errors

# %%
inputs, outputs, targets = run_model_through_dataset(dataloader, model)

print(inputs.shape)
print(outputs.shape)
print(targets.shape)
# Out:
# torch.Size([20361, 18])
# torch.Size([20361, 768])
# torch.Size([20361, 768])

# %%
for i in range(100):
    pred = find_closest_words(i, inputs, outputs, targets)
    print("target word: ", to_word(inputs[i]))
    print("top 3 nearest neighbors: ", pred[:3])
    print()
# Out:
# target word:  med
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'renowned']
#
# target word:  pretty
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  semifinl
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'nnoyed']
#
# target word:  delibertely
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  philhrmonic
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  muir
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'renowned']
#
# target word:  hoisted
# top 3 nearest neighbors:  ['fcilitte', 'nnoyed', 'innovtive']
#
# target word:  dphne
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  performed
# top 3 nearest neighbors:  ['fcilitte', 'terrifying', 'scowled']
#
# target word:  pencil
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  protect
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  leto
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  bertrm
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'scowled']
#
# target word:  ccording
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  disliked
# top 3 nearest neighbors:  ['fcilitte', 'scowled', 'nnoyed']
#
# target word:  pssed
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  wited
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  dediction
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'grimced']
#
# target word:  commercils
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'ctivists']
#
# target word:  prominent
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'nnoyed']
#
# target word:  lighted
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  robotics
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  exterior
# top 3 nearest neighbors:  ['fcilitte', 'terrifying', 'innovtive']
#
# target word:  shows
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  shortlisted
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  ignores
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  qurter
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  brunette
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  descend
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  newsweek
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  nguish
# top 3 nearest neighbors:  ['fcilitte', 'terrifying', 'innovtive']
#
# target word:  emphsize
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'scowled']
#
# target word:  dversry
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'ctivists']
#
# target word:  rck
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  fcing
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  uthors
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  tin
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  disney
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  subscribers
# top 3 nearest neighbors:  ['fcilittes', 'fcilitte', 'fcilitting']
#
# target word:  hussein
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  vlkyrie
# top 3 nearest neighbors:  ['fcilitte', 'grimced', 'fcilittes']
#
# target word:  tome
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'renowned']
#
# target word:  selection
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  cids
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  submerged
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  tesed
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  referred
# top 3 nearest neighbors:  ['fcilitte', 'scowled', 'nnoyed']
#
# target word:  descends
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  triled
# top 3 nearest neighbors:  ['fcilitte', 'nnoyed', 'grimced']
#
# target word:  detiled
# top 3 nearest neighbors:  ['fcilitte', 'scowled', 'innovtive']
#
# target word:  bothering
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  unconventionl
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  looked
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  kill
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  frgmented
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  poorer
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  mbient
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  stemer
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  moreover
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  todd
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'renowned']
#
# target word:  wolverine
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'terrifying']
#
# target word:  nomi
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  olsen
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  ur
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  spnning
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  strid
# top 3 nearest neighbors:  ['fcilitte', 'nnoyed', 'innovtive']
#
# target word:  shrply
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  cylinder
# top 3 nearest neighbors:  ['fcilitte', 'terrifying', 'innovtive']
#
# target word:  flinders
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  exists
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  petition
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  clerly
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'ctivists']
#
# target word:  house
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  ben
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  credible
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  chop
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  rory
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  mrquez
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  rf
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  wong
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'renowned']
#
# target word:  rerview
# top 3 nearest neighbors:  ['fcilitte', 'terrifying', 'innovtive']
#
# target word:  constitution
# top 3 nearest neighbors:  ['fcilitte', 'fcilittes', 'innovtive']
#
# target word:  ejected
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  grief
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  skipped
# top 3 nearest neighbors:  ['fcilitte', 'nnoyed', 'innovtive']
#
# target word:  somebody
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  motif
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  pntheon
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  torh
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  hmilton
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  recited
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  tiled
# top 3 nearest neighbors:  ['fcilitte', 'nnoyed', 'innovtive']
#
# target word:  resemble
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  rchwy
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'nnoyed']
#
# target word:  monterey
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
# target word:  lim
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'enhnce']
#
# target word:  seprted
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'terrifying']
#
# target word:  crp
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'considerble']
#
# target word:  lstly
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']
#
# target word:  thumbs
# top 3 nearest neighbors:  ['fcilitte', 'innovtive', 'fcilittes']

# %%
to_word(inputs[0])
# Out:
# 'med'
